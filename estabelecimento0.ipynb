# %%
import pandas as pd

# %%
df = pd.read_csv('estabelecimento0.csv', encoding = 'latin1', sep = ';')
df
# Out:
# C:\Users\Edson\AppData\Local\Temp\ipykernel_13008\3409278919.py:1: DtypeWarning: Columns (8,18,21,22,24,26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('estabelecimento0.csv', encoding = 'latin1', sep = ';')
#           20765798  0001  70  1   Unnamed: 4  08  20010219  01 Unnamed: 8  \
# 0         76137801     1  65  1          NaN   8  20081231  71        NaN
# 1         61079117   205  56  2          NaN   8  19960527   1        NaN
# 2          6900758     1  62  1          NaN   4  20181016  63        NaN
# 3         38692695     1  92  1          NaN   8  20081231  71        NaN
# 4          4733969     1  22  1  SOUSA PECAS   4  20210422  63        NaN
# ...            ...   ...  .. ..          ...  ..       ...  ..        ...
# 17486898  54718383     1  67  1          NaN   2  20240413   0        NaN
# 17486899  54718394     1  47  1          NaN   2  20240413   0        NaN
# ...

# %%
df.drop(df.tail(1).index, inplace=True)
df
# Out:
#           20765798  0001  70  1   Unnamed: 4  08  20010219  01 Unnamed: 8  \
# 0         76137801     1  65  1          NaN   8  20081231  71        NaN
# 1         61079117   205  56  2          NaN   8  19960527   1        NaN
# 2          6900758     1  62  1          NaN   4  20181016  63        NaN
# 3         38692695     1  92  1          NaN   8  20081231  71        NaN
# 4          4733969     1  22  1  SOUSA PECAS   4  20210422  63        NaN
# ...            ...   ...  .. ..          ...  ..       ...  ..        ...
# 17486897  54718371     1  32  1          NaN   2  20240413   0        NaN
# 17486898  54718383     1  67  1          NaN   2  20240413   0        NaN
# 17486899  54718394     1  47  1          NaN   2  20240413   0        NaN
# 17486900  54718404     1  44  1          NaN   2  20240413   0        NaN
# 17486901  54718415     1  24  1          NaN   2  20240413   0        NaN
#
#           Unnamed: 9  ...  4569  Unnamed: 21 Unnamed: 22 Unnamed: 23  \
# ...
