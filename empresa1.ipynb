# %%
import pandas as pd

# %% [markdown]
# IMPORTAR TABELA

# %%
df = pd.read_csv('empresa1.CSV', encoding = 'latin1', sep = ';')
df
# Out:
#                ,                                 BANCO DO BRASIL SA  2038  10  \
# 0              1  ASSOCIACAO DE AMIGOS DE BAIRRO DO CONJ PAULISTANO  3999  16
# 1              2      WM&R EMPREITEIRA DE CONSTRUCAO CIVIL LIMITADA  2240  49
# 2              3  CASA CARIDADE LUZETE ROBERTA DE MORAIS CONJ PA...  3999  16
# 3              4  ASSOCIACAO DO PEQUENO ADOLECENTE DO CONJ PAULI...  3999  16
# 4              5             SERRALHERIA PORTA DE ACO REAL S/C LTDA  2240  28
# ...          ...                                                ...   ...  ..
# 1048570  1085040                       MARIA MADALENA AZENHA GROSSI  2135  50
# 1048571  1085041      DISLUBEL COMERCIO DE DOCES E MIUDEZAS EM LTDA  2062  49
# 1048572  1085042                                  LUIZ PORTA LUNIOR  2135  50
# 1048573  1085043                 SEMMA COMERCIAL DE CONFECCOES LTDA  2062  49
# 1048574  1085044                            CARLOS CESAR DE SANTANA  2135  50
#
#         1,2E+11    5 Unnamed: 6
# ...

# %% [markdown]
# TIRAR O HEAD (CABEÇALHO)

# %%
df = pd.read_csv('empresa1.CSV', encoding = 'latin1', sep = ';', header=None)
df
# Out:
# C:\Users\Edson\AppData\Local\Temp\ipykernel_10256\1726553040.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('empresa1.CSV', encoding = 'latin1', sep = ';', header=None)
#                0                                                  1     2   3  \
# 0              ,                                 BANCO DO BRASIL SA  2038  10
# 1              1  ASSOCIACAO DE AMIGOS DE BAIRRO DO CONJ PAULISTANO  3999  16
# 2              2      WM&R EMPREITEIRA DE CONSTRUCAO CIVIL LIMITADA  2240  49
# 3              3  CASA CARIDADE LUZETE ROBERTA DE MORAIS CONJ PA...  3999  16
# 4              4  ASSOCIACAO DO PEQUENO ADOLECENTE DO CONJ PAULI...  3999  16
# ...          ...                                                ...   ...  ..
# 1048571  1085040                       MARIA MADALENA AZENHA GROSSI  2135  50
# 1048572  1085041      DISLUBEL COMERCIO DE DOCES E MIUDEZAS EM LTDA  2062  49
# ...

# %% [markdown]
# INSERIR NOVO HEAD (CABEÇALHO)

# %%
df.columns = ['CNPJ', 'INDEFICADOR MATRIZ/FILIAL', 'RAZÃO SOCIAL', 'NOME FANTASIA', 'SITUAÇÃO CADASTRAL',
                    'DATA SITUAÇÃO CADASTRAL', 'CO-PAÍS']
                    
df
# Out:
#             CNPJ                          INDEFICADOR MATRIZ/FILIAL  \
# 0              ,                                 BANCO DO BRASIL SA
# 1              1  ASSOCIACAO DE AMIGOS DE BAIRRO DO CONJ PAULISTANO
# 2              2      WM&R EMPREITEIRA DE CONSTRUCAO CIVIL LIMITADA
# 3              3  CASA CARIDADE LUZETE ROBERTA DE MORAIS CONJ PA...
# 4              4  ASSOCIACAO DO PEQUENO ADOLECENTE DO CONJ PAULI...
# ...          ...                                                ...
# 1048571  1085040                       MARIA MADALENA AZENHA GROSSI
# 1048572  1085041      DISLUBEL COMERCIO DE DOCES E MIUDEZAS EM LTDA
# 1048573  1085042                                  LUIZ PORTA LUNIOR
# 1048574  1085043                 SEMMA COMERCIAL DE CONFECCOES LTDA
# 1048575  1085044                            CARLOS CESAR DE SANTANA
#
#          RAZÃO SOCIAL  NOME FANTASIA SITUAÇÃO CADASTRAL  \
# 0                2038             10            1,2E+11
# ...

# %% [markdown]
# ELIMINAR A ULTIMA LINHA

# %%
df.drop(df.tail(1).index, inplace=True)
df
# Out:
#             CNPJ                          INDEFICADOR MATRIZ/FILIAL  \
# 0              ,                                 BANCO DO BRASIL SA
# 1              1  ASSOCIACAO DE AMIGOS DE BAIRRO DO CONJ PAULISTANO
# 2              2      WM&R EMPREITEIRA DE CONSTRUCAO CIVIL LIMITADA
# 3              3  CASA CARIDADE LUZETE ROBERTA DE MORAIS CONJ PA...
# 4              4  ASSOCIACAO DO PEQUENO ADOLECENTE DO CONJ PAULI...
# ...          ...                                                ...
# 1048570  1085039           COMERCIO DE PECAS AUTOMOTIVAS MAGJO LTDA
# 1048571  1085040                       MARIA MADALENA AZENHA GROSSI
# 1048572  1085041      DISLUBEL COMERCIO DE DOCES E MIUDEZAS EM LTDA
# 1048573  1085042                                  LUIZ PORTA LUNIOR
# 1048574  1085043                 SEMMA COMERCIAL DE CONFECCOES LTDA
#
#          RAZÃO SOCIAL  NOME FANTASIA SITUAÇÃO CADASTRAL  \
# 0                2038             10            1,2E+11
# ...

# %% [markdown]
# EXPORTAR TABELA:

# %%
df.to_csv('n_empresa1.csv', index=False)
df
# Out:
#             CNPJ                          INDEFICADOR MATRIZ/FILIAL  \
# 0              ,                                 BANCO DO BRASIL SA
# 1              1  ASSOCIACAO DE AMIGOS DE BAIRRO DO CONJ PAULISTANO
# 2              2      WM&R EMPREITEIRA DE CONSTRUCAO CIVIL LIMITADA
# 3              3  CASA CARIDADE LUZETE ROBERTA DE MORAIS CONJ PA...
# 4              4  ASSOCIACAO DO PEQUENO ADOLECENTE DO CONJ PAULI...
# ...          ...                                                ...
# 1048570  1085039           COMERCIO DE PECAS AUTOMOTIVAS MAGJO LTDA
# 1048571  1085040                       MARIA MADALENA AZENHA GROSSI
# 1048572  1085041      DISLUBEL COMERCIO DE DOCES E MIUDEZAS EM LTDA
# 1048573  1085042                                  LUIZ PORTA LUNIOR
# 1048574  1085043                 SEMMA COMERCIAL DE CONFECCOES LTDA
#
#          RAZÃO SOCIAL  NOME FANTASIA SITUAÇÃO CADASTRAL  \
# 0                2038             10            1,2E+11
# ...

# %%
df.to_excel('n_empresa1.xlsx', index=False)
df
# Out:
#             CNPJ                          INDEFICADOR MATRIZ/FILIAL  \
# 0              ,                                 BANCO DO BRASIL SA
# 1              1  ASSOCIACAO DE AMIGOS DE BAIRRO DO CONJ PAULISTANO
# 2              2      WM&R EMPREITEIRA DE CONSTRUCAO CIVIL LIMITADA
# 3              3  CASA CARIDADE LUZETE ROBERTA DE MORAIS CONJ PA...
# 4              4  ASSOCIACAO DO PEQUENO ADOLECENTE DO CONJ PAULI...
# ...          ...                                                ...
# 1048570  1085039           COMERCIO DE PECAS AUTOMOTIVAS MAGJO LTDA
# 1048571  1085040                       MARIA MADALENA AZENHA GROSSI
# 1048572  1085041      DISLUBEL COMERCIO DE DOCES E MIUDEZAS EM LTDA
# 1048573  1085042                                  LUIZ PORTA LUNIOR
# 1048574  1085043                 SEMMA COMERCIAL DE CONFECCOES LTDA
#
#          RAZÃO SOCIAL  NOME FANTASIA SITUAÇÃO CADASTRAL  \
# 0                2038             10            1,2E+11
# ...
