# %%
import pandas as pd

# %%
df = pd.read_csv('estabelecimento4.csv', encoding = 'latin1', sep = ';')
df
# Out:
# C:\Users\Edson\AppData\Local\Temp\ipykernel_4820\2483808266.py:1: DtypeWarning: Columns (8,21,22,24,26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('estabelecimento4.csv', encoding = 'latin1', sep = ';')
#          08479581  0002  89  2                         Unnamed: 4  02  \
# 0        15266351     1  16  1                                NaN   4
# 1        15266371     1  97  1                                NaN   8
# 2        15266387     1   8  1                                NaN   8
# 3        15266401     1  65  1  KARLENNE'S PARFUMES DISTRIBUIDORA   4
# 4        15266415     1  89  1                                NaN   4
# ...           ...   ...  .. ..                                ...  ..
# 4753429  65097065     1  42  1                        INTER-PONTO   4
# 4753430  27793017     1   8  1                                NaN   2
# 4753431  65097115     1  91  1                                NaN   8
# ...

# %%
df = pd.read_csv('estabelecimento4.csv', encoding = 'latin1', sep = ';', header=None)
df
# Out:
# C:\Users\Edson\AppData\Local\Temp\ipykernel_4820\1543943707.py:1: DtypeWarning: Columns (8,21,22,24,26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('estabelecimento4.csv', encoding = 'latin1', sep = ';', header=None)
#                0   1   2   3                                  4   5   \
# 0         8479581   2  89   2                                NaN   2
# 1        15266351   1  16   1                                NaN   4
# 2        15266371   1  97   1                                NaN   8
# 3        15266387   1   8   1                                NaN   8
# 4        15266401   1  65   1  KARLENNE'S PARFUMES DISTRIBUIDORA   4
# ...           ...  ..  ..  ..                                ...  ..
# 4753430  65097065   1  42   1                        INTER-PONTO   4
# 4753431  27793017   1   8   1                                NaN   2
# 4753432  65097115   1  91   1                                NaN   8
# ...

# %%
df.columns = ['DESCRIÇÃO TIPO LOGRADOURO', 'LOGRADOURO', 'NUMERO', 'COMPLEMENTO', 'BAIRRO', 'CEP',
                'UF', 'CODIGO MUNICIPIO', 'MUNICIPIO', 'DDD-TELEFONE-1', 'DDD', 'TELEFONE-1', 'DDD-TELEFONE-2',
                'DDD-2', 'TELEFONE-2', 'DDD-FAX', 'NU-DDD-FAX', 'NU-FAX', 'CORREIO ELETRONICO', 
                'QUALIFICAÇÃO DO RESPONSÁVEL', 'CAPITAL SOCIAL DA EMPRESA', 'PORTE-EMPRESA', 'OPÇÃO PELO SIMPLES',
                'DATA OPCAO PELO SIMPLES', 'DATA EXCLUSÃO DO SIMPLES', 'OPÇÃO PELO MEI', 'SITUAÇÃO ESPECIAL',
                'DATA SITUAÇÃO ESPECIAL', 'FILLER', 'FIM DE REGISTRO']
df
# Out:
#          DESCRIÇÃO TIPO LOGRADOURO  LOGRADOURO  NUMERO  COMPLEMENTO  \
# 0                          8479581           2      89            2
# 1                         15266351           1      16            1
# 2                         15266371           1      97            1
# 3                         15266387           1       8            1
# 4                         15266401           1      65            1
# ...                            ...         ...     ...          ...
# 4753430                   65097065           1      42            1
# 4753431                   27793017           1       8            1
# 4753432                   65097115           1      91            1
# 4753433                   83758946           1      49            1
# 4753434                   48266027           1      57            1
#
#                                     BAIRRO  CEP        UF  CODIGO MUNICIPIO  \
# ...

# %%
df.drop(df.tail(1).index, inplace=True)
df
# Out:
#          DESCRIÇÃO TIPO LOGRADOURO  LOGRADOURO  NUMERO  COMPLEMENTO  \
# 0                          8479581           2      89            2
# 1                         15266351           1      16            1
# 2                         15266371           1      97            1
# 3                         15266387           1       8            1
# 4                         15266401           1      65            1
# ...                            ...         ...     ...          ...
# 4753429                   83758789           1      71            1
# 4753430                   65097065           1      42            1
# 4753431                   27793017           1       8            1
# 4753432                   65097115           1      91            1
# 4753433                   83758946           1      49            1
#
#                                     BAIRRO  CEP        UF  CODIGO MUNICIPIO  \
# ...

# %%
df.to_csv('n_estabelecimento4.csv', index=False)
df
# Out:
#          DESCRIÇÃO TIPO LOGRADOURO  LOGRADOURO  NUMERO  COMPLEMENTO  \
# 0                          8479581           2      89            2
# 1                         15266351           1      16            1
# 2                         15266371           1      97            1
# 3                         15266387           1       8            1
# 4                         15266401           1      65            1
# ...                            ...         ...     ...          ...
# 4753429                   83758789           1      71            1
# 4753430                   65097065           1      42            1
# 4753431                   27793017           1       8            1
# 4753432                   65097115           1      91            1
# 4753433                   83758946           1      49            1
#
#                                     BAIRRO  CEP        UF  CODIGO MUNICIPIO  \
# ...
