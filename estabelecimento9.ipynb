# %%
import pandas as pd

# %%
df = pd.read_csv('estabelecimento9.csv', encoding = 'latin1', sep = ';')
df
# Out:
# C:\Users\Edson\AppData\Local\Temp\ipykernel_5764\1115042560.py:1: DtypeWarning: Columns (8,21,22,24,25,26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('estabelecimento9.csv', encoding = 'latin1', sep = ';')
#          79242905  0001  28  1                              Unnamed: 4  08  \
# 0        47041223     1  60  1                                     NaN   2
# 1         4938273     1  32  1                                     NaN   2
# 2         5561924     1  80  1                                     NaN   8
# 3        42005868     1  24  1                                     NaN   8
# 4         2054384     1  50  1                 IVO COMERCIO & SERVICOS   4
# ...           ...   ...  .. ..                                     ...  ..
# 4753429  24513020     4  77  2                         TRANSFIGUEIREDO   8
# 4753430  24514093     2  11  2                                     NaN   8
# 4753431   5991530     1  62  1  CENTRO DE FORMACAO DE CONDUTORES VANTE   2
# 4753432  24515793     2  20  2                           LOJAS RIBAMAR   2
# 4753433   2600132     1  80  1                                   TROON   2
#
#          19870122  01 Unnamed: 8  Unnamed: 9  ...  8173  Unnamed: 21  \
# 0        20051103   0        NaN         NaN  ...  6425         16.0
# 1        20020131   0        NaN         NaN  ...  7963         41.0
# 2        20050516   1        NaN         NaN  ...  6131         19.0
# 3        19960630   1        NaN         NaN  ...  3313          NaN
# 4        20181025  63        NaN         NaN  ...  2491         81.0
# ...           ...  ..        ...         ...  ...   ...          ...
# 4753429  19951228   1        NaN         NaN  ...  1761          NaN
# 4753430  20081231  71        NaN         NaN  ...  1981          NaN
# 4753431  20051103   0        NaN         NaN  ...  4701         38.0
# 4753432  20010526   0        NaN         NaN  ...  1639         84.0
# 4753433  20010225   0        NaN         NaN  ...  7107         11.0
#
#         Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26  \
# 0          37216090        16.0  37014022.0        16.0    37014022
# 1           2292148         NaN         NaN        41.0     2292148
# 2          34651679         NaN         NaN         NaN         NaN
# 3               NaN         NaN         NaN         NaN         NaN
# 4           4264607         NaN         NaN         NaN         NaN
# ...             ...         ...         ...         ...         ...
# 4753429         NaN         NaN         NaN         NaN         NaN
# 4753430         NaN         NaN         NaN         NaN         NaN
# 4753431  38213634.0         NaN         NaN         NaN         NaN
# 4753432  34211688.0        84.0  96849190.0        84.0  34211567.0
# 4753433  30446555.0         NaN         NaN         NaN         NaN
#
#                                 Unnamed: 27  Unnamed: 28 Unnamed: 29
# 0        ASSEMBLEIADEDEUSFRANCA@HOTMAIL.COM          NaN         NaN
# 1                                       NaN          NaN         NaN
# 2                                       NaN          NaN         NaN
# 3                                       NaN          NaN         NaN
# 4                                       NaN          NaN         NaN
# ...                                     ...          ...         ...
# 4753429                                 NaN          NaN         NaN
# 4753430                                 NaN          NaN         NaN
# 4753431           AUTOESCOLAVANTE@GMAIL.COM          NaN         NaN
# 4753432       FMCONTABILIDADE2012@GMAIL.COM          NaN         NaN
# 4753433            JLPINTO@MONTBLANC.COM.BS          NaN         NaN
#
# [4753434 rows x 30 columns]

# %%
df = pd.read_csv('estabelecimento9.csv', encoding = 'latin1', sep = ';', header=None)
df
# Out:
# C:\Users\Edson\AppData\Local\Temp\ipykernel_5764\2859765701.py:1: DtypeWarning: Columns (8,10,21,22,24,25,26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('estabelecimento9.csv', encoding = 'latin1', sep = ';', header=None)
#                0   1   2   3                                       4   5   \
# 0        79242905   1  28   1                                     NaN   8
# 1        47041223   1  60   1                                     NaN   2
# 2         4938273   1  32   1                                     NaN   2
# 3         5561924   1  80   1                                     NaN   8
# 4        42005868   1  24   1                                     NaN   8
# ...           ...  ..  ..  ..                                     ...  ..
# 4753430  24513020   4  77   2                         TRANSFIGUEIREDO   8
# 4753431  24514093   2  11   2                                     NaN   8
# 4753432   5991530   1  62   1  CENTRO DE FORMACAO DE CONDUTORES VANTE   2
# 4753433  24515793   2  20   2                           LOJAS RIBAMAR   2
# 4753434   2600132   1  80   1                                   TROON   2
#
#                6   7    8   9   ...    20    21          22    23          24  \
# 0        19870122   1  NaN NaN  ...  8173   NaN         NaN   NaN         NaN
# 1        20051103   0  NaN NaN  ...  6425  16.0    37216090  16.0  37014022.0
# 2        20020131   0  NaN NaN  ...  7963  41.0     2292148   NaN         NaN
# 3        20050516   1  NaN NaN  ...  6131  19.0    34651679   NaN         NaN
# 4        19960630   1  NaN NaN  ...  3313   NaN         NaN   NaN         NaN
# ...           ...  ..  ...  ..  ...   ...   ...         ...   ...         ...
# 4753430  19951228   1  NaN NaN  ...  1761   NaN         NaN   NaN         NaN
# 4753431  20081231  71  NaN NaN  ...  1981   NaN         NaN   NaN         NaN
# 4753432  20051103   0  NaN NaN  ...  4701  38.0  38213634.0   NaN         NaN
# 4753433  20010526   0  NaN NaN  ...  1639  84.0  34211688.0  84.0  96849190.0
# 4753434  20010225   0  NaN NaN  ...  7107  11.0  30446555.0   NaN         NaN
#
#            25          26                                  27   28  29
# 0         NaN         NaN                                 NaN  NaN NaN
# 1        16.0    37014022  ASSEMBLEIADEDEUSFRANCA@HOTMAIL.COM  NaN NaN
# 2        41.0     2292148                                 NaN  NaN NaN
# 3         NaN         NaN                                 NaN  NaN NaN
# 4         NaN         NaN                                 NaN  NaN NaN
# ...       ...         ...                                 ...  ...  ..
# 4753430   NaN         NaN                                 NaN  NaN NaN
# 4753431   NaN         NaN                                 NaN  NaN NaN
# 4753432   NaN         NaN           AUTOESCOLAVANTE@GMAIL.COM  NaN NaN
# 4753433  84.0  34211567.0       FMCONTABILIDADE2012@GMAIL.COM  NaN NaN
# 4753434   NaN         NaN            JLPINTO@MONTBLANC.COM.BS  NaN NaN
#
# [4753435 rows x 30 columns]

# %%
df.columns = ['DESCRIÇÃO TIPO LOGRADOURO', 'LOGRADOURO', 'NUMERO', 'COMPLEMENTO', 'BAIRRO', 'CEP',
                'UF', 'CODIGO MUNICIPIO', 'MUNICIPIO', 'DDD-TELEFONE-1', 'DDD', 'TELEFONE-1', 'DDD-TELEFONE-2',
                'DDD-2', 'TELEFONE-2', 'DDD-FAX', 'NU-DDD-FAX', 'NU-FAX', 'CORREIO ELETRONICO', 
                'QUALIFICAÇÃO DO RESPONSÁVEL', 'CAPITAL SOCIAL DA EMPRESA', 'PORTE-EMPRESA', 'OPÇÃO PELO SIMPLES',
                'DATA OPCAO PELO SIMPLES', 'DATA EXCLUSÃO DO SIMPLES', 'OPÇÃO PELO MEI', 'SITUAÇÃO ESPECIAL',
                'DATA SITUAÇÃO ESPECIAL', 'FILLER', 'FIM DE REGISTRO']
df
# Out:
#          DESCRIÇÃO TIPO LOGRADOURO  LOGRADOURO  NUMERO  COMPLEMENTO  \
# 0                         79242905           1      28            1
# 1                         47041223           1      60            1
# 2                          4938273           1      32            1
# 3                          5561924           1      80            1
# 4                         42005868           1      24            1
# ...                            ...         ...     ...          ...
# 4753430                   24513020           4      77            2
# 4753431                   24514093           2      11            2
# 4753432                    5991530           1      62            1
# 4753433                   24515793           2      20            2
# 4753434                    2600132           1      80            1
#
#                                          BAIRRO  CEP        UF  \
# 0                                           NaN    8  19870122
# 1                                           NaN    2  20051103
# 2                                           NaN    2  20020131
# 3                                           NaN    8  20050516
# 4                                           NaN    8  19960630
# ...                                         ...  ...       ...
# 4753430                         TRANSFIGUEIREDO    8  19951228
# 4753431                                     NaN    8  20081231
# 4753432  CENTRO DE FORMACAO DE CONDUTORES VANTE    2  20051103
# 4753433                           LOJAS RIBAMAR    2  20010526
# 4753434                                   TROON    2  20010225
#
#          CODIGO MUNICIPIO MUNICIPIO  DDD-TELEFONE-1  ...  \
# 0                       1       NaN             NaN  ...
# 1                       0       NaN             NaN  ...
# 2                       0       NaN             NaN  ...
# 3                       1       NaN             NaN  ...
# 4                       1       NaN             NaN  ...
# ...                   ...       ...             ...  ...
# 4753430                 1       NaN             NaN  ...
# 4753431                71       NaN             NaN  ...
# 4753432                 0       NaN             NaN  ...
# 4753433                 0       NaN             NaN  ...
# 4753434                 0       NaN             NaN  ...
#
#         CAPITAL SOCIAL DA EMPRESA  PORTE-EMPRESA OPÇÃO PELO SIMPLES  \
# 0                            8173            NaN                NaN
# 1                            6425           16.0           37216090
# 2                            7963           41.0            2292148
# 3                            6131           19.0           34651679
# 4                            3313            NaN                NaN
# ...                           ...            ...                ...
# 4753430                      1761            NaN                NaN
# 4753431                      1981            NaN                NaN
# 4753432                      4701           38.0         38213634.0
# 4753433                      1639           84.0         34211688.0
# 4753434                      7107           11.0         30446555.0
#
#         DATA OPCAO PELO SIMPLES DATA EXCLUSÃO DO SIMPLES OPÇÃO PELO MEI  \
# 0                           NaN                      NaN            NaN
# 1                          16.0               37014022.0           16.0
# 2                           NaN                      NaN           41.0
# 3                           NaN                      NaN            NaN
# 4                           NaN                      NaN            NaN
# ...                         ...                      ...            ...
# 4753430                     NaN                      NaN            NaN
# 4753431                     NaN                      NaN            NaN
# 4753432                     NaN                      NaN            NaN
# 4753433                    84.0               96849190.0           84.0
# 4753434                     NaN                      NaN            NaN
#
#         SITUAÇÃO ESPECIAL              DATA SITUAÇÃO ESPECIAL  FILLER  \
# 0                     NaN                                 NaN     NaN
# 1                37014022  ASSEMBLEIADEDEUSFRANCA@HOTMAIL.COM     NaN
# 2                 2292148                                 NaN     NaN
# 3                     NaN                                 NaN     NaN
# 4                     NaN                                 NaN     NaN
# ...                   ...                                 ...     ...
# 4753430               NaN                                 NaN     NaN
# 4753431               NaN                                 NaN     NaN
# 4753432               NaN           AUTOESCOLAVANTE@GMAIL.COM     NaN
# 4753433        34211567.0       FMCONTABILIDADE2012@GMAIL.COM     NaN
# 4753434               NaN            JLPINTO@MONTBLANC.COM.BS     NaN
#
#         FIM DE REGISTRO
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 4753430             NaN
# 4753431             NaN
# 4753432             NaN
# 4753433             NaN
# 4753434             NaN
#
# [4753435 rows x 30 columns]

# %%
df.drop(df.tail(1).index, inplace=True)
df
# Out:
#          DESCRIÇÃO TIPO LOGRADOURO  LOGRADOURO  NUMERO  COMPLEMENTO  \
# 0                         79242905           1      28            1
# 1                         47041223           1      60            1
# 2                          4938273           1      32            1
# 3                          5561924           1      80            1
# 4                         42005868           1      24            1
# ...                            ...         ...     ...          ...
# 4753429                   24512592           2      70            2
# 4753430                   24513020           4      77            2
# 4753431                   24514093           2      11            2
# 4753432                    5991530           1      62            1
# 4753433                   24515793           2      20            2
#
#                                          BAIRRO  CEP        UF  \
# 0                                           NaN    8  19870122
# 1                                           NaN    2  20051103
# 2                                           NaN    2  20020131
# 3                                           NaN    8  20050516
# 4                                           NaN    8  19960630
# ...                                         ...  ...       ...
# 4753429                                     NaN    4  20181120
# 4753430                         TRANSFIGUEIREDO    8  19951228
# 4753431                                     NaN    8  20081231
# 4753432  CENTRO DE FORMACAO DE CONDUTORES VANTE    2  20051103
# 4753433                           LOJAS RIBAMAR    2  20010526
#
#          CODIGO MUNICIPIO MUNICIPIO  DDD-TELEFONE-1  ...  \
# 0                       1       NaN             NaN  ...
# 1                       0       NaN             NaN  ...
# 2                       0       NaN             NaN  ...
# 3                       1       NaN             NaN  ...
# 4                       1       NaN             NaN  ...
# ...                   ...       ...             ...  ...
# 4753429                63       NaN             NaN  ...
# 4753430                 1       NaN             NaN  ...
# 4753431                71       NaN             NaN  ...
# 4753432                 0       NaN             NaN  ...
# 4753433                 0       NaN             NaN  ...
#
#         CAPITAL SOCIAL DA EMPRESA  PORTE-EMPRESA OPÇÃO PELO SIMPLES  \
# 0                            8173            NaN                NaN
# 1                            6425           16.0           37216090
# 2                            7963           41.0            2292148
# 3                            6131           19.0           34651679
# 4                            3313            NaN                NaN
# ...                           ...            ...                ...
# 4753429                      5623            NaN                NaN
# 4753430                      1761            NaN                NaN
# 4753431                      1981            NaN                NaN
# 4753432                      4701           38.0         38213634.0
# 4753433                      1639           84.0         34211688.0
#
#         DATA OPCAO PELO SIMPLES DATA EXCLUSÃO DO SIMPLES OPÇÃO PELO MEI  \
# 0                           NaN                      NaN            NaN
# 1                          16.0               37014022.0           16.0
# 2                           NaN                      NaN           41.0
# 3                           NaN                      NaN            NaN
# 4                           NaN                      NaN            NaN
# ...                         ...                      ...            ...
# 4753429                     NaN                      NaN            NaN
# 4753430                     NaN                      NaN            NaN
# 4753431                     NaN                      NaN            NaN
# 4753432                     NaN                      NaN            NaN
# 4753433                    84.0               96849190.0           84.0
#
#         SITUAÇÃO ESPECIAL              DATA SITUAÇÃO ESPECIAL  FILLER  \
# 0                     NaN                                 NaN     NaN
# 1                37014022  ASSEMBLEIADEDEUSFRANCA@HOTMAIL.COM     NaN
# 2                 2292148                                 NaN     NaN
# 3                     NaN                                 NaN     NaN
# 4                     NaN                                 NaN     NaN
# ...                   ...                                 ...     ...
# 4753429               NaN                                 NaN     NaN
# 4753430               NaN                                 NaN     NaN
# 4753431               NaN                                 NaN     NaN
# 4753432               NaN           AUTOESCOLAVANTE@GMAIL.COM     NaN
# 4753433        34211567.0       FMCONTABILIDADE2012@GMAIL.COM     NaN
#
#         FIM DE REGISTRO
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 4753429             NaN
# 4753430             NaN
# 4753431             NaN
# 4753432             NaN
# 4753433             NaN
#
# [4753434 rows x 30 columns]

# %%
df.to_csv('n_estabelecimento9.csv', index=False)
df
# Out:
#          DESCRIÇÃO TIPO LOGRADOURO  LOGRADOURO  NUMERO  COMPLEMENTO  \
# 0                         79242905           1      28            1
# 1                         47041223           1      60            1
# 2                          4938273           1      32            1
# 3                          5561924           1      80            1
# 4                         42005868           1      24            1
# ...                            ...         ...     ...          ...
# 4753429                   24512592           2      70            2
# 4753430                   24513020           4      77            2
# 4753431                   24514093           2      11            2
# 4753432                    5991530           1      62            1
# 4753433                   24515793           2      20            2
#
#                                          BAIRRO  CEP        UF  \
# 0                                           NaN    8  19870122
# 1                                           NaN    2  20051103
# 2                                           NaN    2  20020131
# 3                                           NaN    8  20050516
# 4                                           NaN    8  19960630
# ...                                         ...  ...       ...
# 4753429                                     NaN    4  20181120
# 4753430                         TRANSFIGUEIREDO    8  19951228
# 4753431                                     NaN    8  20081231
# 4753432  CENTRO DE FORMACAO DE CONDUTORES VANTE    2  20051103
# 4753433                           LOJAS RIBAMAR    2  20010526
#
#          CODIGO MUNICIPIO MUNICIPIO  DDD-TELEFONE-1  ...  \
# 0                       1       NaN             NaN  ...
# 1                       0       NaN             NaN  ...
# 2                       0       NaN             NaN  ...
# 3                       1       NaN             NaN  ...
# 4                       1       NaN             NaN  ...
# ...                   ...       ...             ...  ...
# 4753429                63       NaN             NaN  ...
# 4753430                 1       NaN             NaN  ...
# 4753431                71       NaN             NaN  ...
# 4753432                 0       NaN             NaN  ...
# 4753433                 0       NaN             NaN  ...
#
#         CAPITAL SOCIAL DA EMPRESA  PORTE-EMPRESA OPÇÃO PELO SIMPLES  \
# 0                            8173            NaN                NaN
# 1                            6425           16.0           37216090
# 2                            7963           41.0            2292148
# 3                            6131           19.0           34651679
# 4                            3313            NaN                NaN
# ...                           ...            ...                ...
# 4753429                      5623            NaN                NaN
# 4753430                      1761            NaN                NaN
# 4753431                      1981            NaN                NaN
# 4753432                      4701           38.0         38213634.0
# 4753433                      1639           84.0         34211688.0
#
#         DATA OPCAO PELO SIMPLES DATA EXCLUSÃO DO SIMPLES OPÇÃO PELO MEI  \
# 0                           NaN                      NaN            NaN
# 1                          16.0               37014022.0           16.0
# 2                           NaN                      NaN           41.0
# 3                           NaN                      NaN            NaN
# 4                           NaN                      NaN            NaN
# ...                         ...                      ...            ...
# 4753429                     NaN                      NaN            NaN
# 4753430                     NaN                      NaN            NaN
# 4753431                     NaN                      NaN            NaN
# 4753432                     NaN                      NaN            NaN
# 4753433                    84.0               96849190.0           84.0
#
#         SITUAÇÃO ESPECIAL              DATA SITUAÇÃO ESPECIAL  FILLER  \
# 0                     NaN                                 NaN     NaN
# 1                37014022  ASSEMBLEIADEDEUSFRANCA@HOTMAIL.COM     NaN
# 2                 2292148                                 NaN     NaN
# 3                     NaN                                 NaN     NaN
# 4                     NaN                                 NaN     NaN
# ...                   ...                                 ...     ...
# 4753429               NaN                                 NaN     NaN
# 4753430               NaN                                 NaN     NaN
# 4753431               NaN                                 NaN     NaN
# 4753432               NaN           AUTOESCOLAVANTE@GMAIL.COM     NaN
# 4753433        34211567.0       FMCONTABILIDADE2012@GMAIL.COM     NaN
#
#         FIM DE REGISTRO
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 4753429             NaN
# 4753430             NaN
# 4753431             NaN
# 4753432             NaN
# 4753433             NaN
#
# [4753434 rows x 30 columns]
