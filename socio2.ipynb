# %%
import pandas as pd

# %%
df = pd.read_csv('socio2.CSV', encoding='LATIN-1', sep=';')
df
# Out:
#          41623537  2 ELISABETE SOARES DE FREITAS RODRIGUES  ***212774**  22  \
# 0        41623559  2                AGNALDO DOS ANJOS GOIS  ***222711**  49
# 1        41623572  2      CAIO COSTA SANTOS ALVES DA SILVA  ***981752**  49
# 2        41623603  2       MONIQUE EVELLE NASCIMENTO COSTA  ***488415**  49
# 3        41623603  2     LUCAS ROBERTO DA COSTA DE SANTANA  ***125625**  22
# 4        41623615  2                  ALINE MIRANDA LISBOA  ***694036**  49
# ...           ... ..                                   ...          ...  ..
# 1048570   7784728  2                      DOUGLAS DOS REIS  ***386908**  49
# 1048571   7784728  2       DOUGLAS JERICO DE CARVALHO REIS  ***909078**  22
# 1048572   7784737  2              FERNANDA MARA DOS SANTOS  ***641768**  49
# 1048573   7784737  2        HELENA MARA BARBOSA DOS SANTOS  ***312128**  22
# 1048574   7784753  2           WANDERLEY RESENDE DOMINGUES  ***529308**  49
#
# ...

# %%
df = pd.read_csv('socio2.CSV', encoding='LATIN-1', sep=';', header=None)
df
# Out:
#                0   1                                      2            3   4   \
# 0        41623537   2  ELISABETE SOARES DE FREITAS RODRIGUES  ***212774**  22
# 1        41623559   2                 AGNALDO DOS ANJOS GOIS  ***222711**  49
# 2        41623572   2       CAIO COSTA SANTOS ALVES DA SILVA  ***981752**  49
# 3        41623603   2        MONIQUE EVELLE NASCIMENTO COSTA  ***488415**  49
# 4        41623603   2      LUCAS ROBERTO DA COSTA DE SANTANA  ***125625**  22
# ...           ...  ..                                    ...          ...  ..
# 1048571   7784728   2                       DOUGLAS DOS REIS  ***386908**  49
# 1048572   7784728   2        DOUGLAS JERICO DE CARVALHO REIS  ***909078**  22
# 1048573   7784737   2               FERNANDA MARA DOS SANTOS  ***641768**  49
# 1048574   7784737   2         HELENA MARA BARBOSA DOS SANTOS  ***312128**  22
# 1048575   7784753   2            WANDERLEY RESENDE DOMINGUES  ***529308**  49
#
# ...

# %%
df.columns = ['CNPJ', 'INDEFICADOR MATRIZ/FILIAL', 'RAZÃO SOCIAL', 'NOME FANTASIA', 'SITUAÇÃO CADASTRAL',
              'DATA SITUAÇÃO CADASTRAL', 'MOTIVO SITUAÇÃO CADASTRAL', 'CO-PAÍS', 
              'CÓDIGO NATUREZA JURIDICA', 'DATA INICIO ATIVIDADE', 'CNAE-FISCAL']
df
# Out:
#              CNPJ  INDEFICADOR MATRIZ/FILIAL  \
# 0        41623537                          2
# 1        41623559                          2
# 2        41623572                          2
# 3        41623603                          2
# 4        41623603                          2
# ...           ...                        ...
# 1048571   7784728                          2
# 1048572   7784728                          2
# 1048573   7784737                          2
# 1048574   7784737                          2
# 1048575   7784753                          2
#
#                                   RAZÃO SOCIAL NOME FANTASIA  \
# 0        ELISABETE SOARES DE FREITAS RODRIGUES   ***212774**
# 1                       AGNALDO DOS ANJOS GOIS   ***222711**
# 2             CAIO COSTA SANTOS ALVES DA SILVA   ***981752**
# 3              MONIQUE EVELLE NASCIMENTO COSTA   ***488415**
# 4            LUCAS ROBERTO DA COSTA DE SANTANA   ***125625**
# ...

# %%
df.drop(df.tail(1).index, inplace=True)
df
# Out:
#              CNPJ  INDEFICADOR MATRIZ/FILIAL  \
# 0        41623537                          2
# 1        41623559                          2
# 2        41623572                          2
# 3        41623603                          2
# 4        41623603                          2
# ...           ...                        ...
# 1048570   7784699                          2
# 1048571   7784728                          2
# 1048572   7784728                          2
# 1048573   7784737                          2
# 1048574   7784737                          2
#
#                                   RAZÃO SOCIAL NOME FANTASIA  \
# 0        ELISABETE SOARES DE FREITAS RODRIGUES   ***212774**
# 1                       AGNALDO DOS ANJOS GOIS   ***222711**
# 2             CAIO COSTA SANTOS ALVES DA SILVA   ***981752**
# 3              MONIQUE EVELLE NASCIMENTO COSTA   ***488415**
# 4            LUCAS ROBERTO DA COSTA DE SANTANA   ***125625**
# ...

# %%
df.to_csv('n_socio2.csv', index=False)
df
# Out:
#              CNPJ  INDEFICADOR MATRIZ/FILIAL  \
# 0        41623537                          2
# 1        41623559                          2
# 2        41623572                          2
# 3        41623603                          2
# 4        41623603                          2
# ...           ...                        ...
# 1048570   7784699                          2
# 1048571   7784728                          2
# 1048572   7784728                          2
# 1048573   7784737                          2
# 1048574   7784737                          2
#
#                                   RAZÃO SOCIAL NOME FANTASIA  \
# 0        ELISABETE SOARES DE FREITAS RODRIGUES   ***212774**
# 1                       AGNALDO DOS ANJOS GOIS   ***222711**
# 2             CAIO COSTA SANTOS ALVES DA SILVA   ***981752**
# 3              MONIQUE EVELLE NASCIMENTO COSTA   ***488415**
# 4            LUCAS ROBERTO DA COSTA DE SANTANA   ***125625**
# ...
